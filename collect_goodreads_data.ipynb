# %% [markdown]
# <a href="https://colab.research.google.com/github/carrieacheung/rory-gilmore-booklist-analysis/blob/main/collect_goodreads_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries

from bs4 import BeautifulSoup
import requests
import re
import collections
import time
import pandas as pd

# %%
def get_title(soup):
  '''
  get_title extracts the book title from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :title: {string} The title of the book
  '''
  try:
    find_title = soup.find('h1', {'id': 'bookTitle'}) # Finds the <h1> tag containing the book title
    title = find_title.get_text(strip=True) # Extracts just the text from the <h1> tag 
  except:
    title = '' # If no title is found
  return title

# %%
def get_book_number(soup):
  '''
  get_book_number extracts the book number from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :book_number: {string} The number of the book in the series
  '''
  try:
    find_series = soup.find('h2', {'id': 'bookSeries'}) # Finds the <h2> tag containing the <a> tag
    find_series_details = find_series.find('a') # Finds the <a> tag containing the series details
    series_details = find_series_details.get_text(strip=True) # Extracts just the text from the <a> tag 
    book_number = re.findall(r"#(\d+)", series_details)[0] # Finds the book number from the extracted text
  except:
    book_number = '' # If no book number is found
  return book_number

# %%
def get_series_title(soup):
  '''
  get_series_title extracts the series title from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :series_title: {string} The title of the series the book is in
  '''
  try:
    find_series = soup.find('h2', {'id': 'bookSeries'}) # Finds the <h2> tag containing the <a> tag
    find_series_details = find_series.find('a') # Finds the <a> tag containing the series details
    series_details = find_series_details.get_text(strip=True) # Extracts just the text from the <a> tag
    series_title = re.findall(r"\(([^)]*)\s#", series_details)[0] # Finds the series title from the extracted text
  except:
    series_title = '' # If no series title is found
  return series_title

# %%
def get_series_length(soup):
  '''
  get_series_length extracts the length of the from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :series_length: {string} The length of the series that the book is in
  '''
  try:
    find_series_list = soup.find('div', {'class': 'seriesList'}) # Finds the <div> tag containing the <span> tag
    find_series_span = find_series_list.find('span') # Finds the <span> tag nested at the same level as the series length
    find_series_length = find_series_span.next_sibling.strip() # Finds text containing the series length
    series_length = re.findall(r"(\d+)\sbooks", find_series_length)[0] # Finds the series length from the text
  except:
    series_length = '' # If no series length is found
  return series_length

# %%
def get_author(soup):
  '''
  get_author extracts the author(s) from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :author: {string} The author(s) comma seperated
  '''
  try:
    author_dict = collections.defaultdict(list) # Initializes a dictionary that allows new keys to be added
    find_author_container = soup.find_all('div', {'class': 'authorName__container'}) # Finds all the <div> tags containing author information
    for author_details in find_author_container: # Loops through each author element
      find_author_name = author_details.find('span', {'itemprop': 'name'}) # Finds the <span> tag containing the author's name
      author_name = find_author_name.get_text(strip=True) # Extracts just the text from the <span> name tag
      find_author_label = author_details.find('span', {'class': 'greyText'}) # Finds the <span> tag containing the author's label
      if find_author_label: 
        author_label = find_author_label.get_text(strip=True) # Extracts just the text from the <span> label tag
        author_dict[author_label].append(author_name) # Creates a list of authors for each label in a dictionary
      else:
        author_dict['(Goodreads Author)'].append(author_name) # Authors without a label are labelled as 'Goodreads Author'
    author = ', '.join(author_dict['(Goodreads Author)']) # Joins the author(s) comma separated
  except:
    author = '' # If no author is found
  return author

# %%
def get_publication_date(soup):
  '''
  get_publication_date extracts the month, day and year of publication from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :publication_date: {list} Contains strings of the month, day and year 
  '''
  try:
    find_date = soup.find('nobr', {'class': 'greyText'}) # Finds <nobr> tag containing the publication date
    if find_date:
      pass
    else:
      find_date = soup.find('div', {'id': 'details'}) # If no <nobr> tag is found, finds the publication date from a different tag
    date = find_date.get_text(strip=True) # Extracts just the text from the tag
    try:
      month = re.findall(r'ublished.*?(January|February|March|April|May|June|July|August|September|October|November|December)', date)[0] # Finds the month from the text
    except:
      month = '' # If no month is found
    try:
      day = re.findall(r'ublished.*?(\d{1,2})', date)[0] # Finds the day from the text
    except:
      day = '' # If no day is found
    try:
      year = re.findall(r'ublished.*?(\d{4})', date)[0] # Finds the year from the text
    except:
      year = '' # If no year is found
    publication_date = [month, day, year] # Saves month, day and year in a list
  except:
    publication_date = ['', '', ''] # If month, day and year are not found
  return publication_date

# %%
def get_number_of_pages(soup):
  '''
  get_number_of_pages extracts the number of pages in the book from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :publication_date: {string} The number of pages
  '''
  try:
    find_pages = soup.find('span', {'itemprop': 'numberOfPages'}) # Finds the <span> tag containing the number of pages
    pages = find_pages.get_text(strip=True) # Extracts just the text from the tag
    number_of_pages = re.findall(r'\b\d+\b', pages)[0] # Finds the number of pages from the text
  except:
    number_of_pages = '' # If the number of pages is not found
  return number_of_pages

# %%
def get_genres(soup):
  '''
  get_genres extracts the genres of book from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :genres: {string} The genres of the book comma seperated
  '''
  try:
    genre_list = [] # Initializes a list
    find_genre_list = soup.find_all('div', {'class': 'elementList'}) # Finds all the <div> tags containing the genres
    for genre_details in find_genre_list: # Loops through each genre
      find_genre = genre_details.find_all('a', {'class': 'actionLinkLite bookPageGenreLink'}) # Finds all the <a> tags containing the genre and subgenre
      main_genre = find_genre[-1] # If a subgenre is present this becomes the main genre, else the main genre is just the genre
      genre = main_genre.get_text(strip=True) # Extracts just the text from the tag
      genre_list.append(genre) # Adds the genre to the list
    genres = ', '.join(genre_list) # Joins the genres comma seperated
  except: 
    genres = '' # If the genres are not found
  return genres

# %%
def get_similar_books(soup):
  '''
  get_similar_books extracts all of the similar books from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :rating_value: {string} A list of all the similar books
  '''
  try:
    similar_books_list = [] # Initialize list 
    find_similar_book_carousel = soup.find('div', {'class': 'bookCarousel'}) # Finds <div> tag containing <li> tags
    find_similar_books = find_similar_book_carousel.find_all('li', {'class': 'cover'}) # Finds all the <li> tags containg the similar book details
    for similar_book_details in find_similar_books: # Loops through the similar books
      try:
        similar_book_title = similar_book_details.find('img')['alt'] # The title of a similar book
        similar_book_author = re.findall(r'(?<=\\">)(.+?)(?=<)', str(similar_book_details))[1] # The author or a similar book
        similar_book = similar_book_title + ' by ' + similar_book_author # Combines the title and author
        similar_books_list.append(similar_book) # Add the similar book to the list
      except:
        pass
    similar_books = ',, '.join(similar_books_list) # Join the list together, comma seperated
  except:
    similar_books = '' # If the similar books are not found
  return similar_books

# %%
def get_rating_value(soup):
  '''
  get_rating_value extracts the rating value of the book from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :rating_value: {string} The rating value 0.00 - 5.00
  '''
  try:
    find_rating_value = soup.find('span', {'itemprop': 'ratingValue'}) # Finds the <span> tag containing the rating value
    rating_value = find_rating_value.get_text(strip=True) # Extracts just the text from the tag
  except:
    rating_value = '' # If the rating value is not found
  return rating_value

# %%
def get_number_of_ratings(soup):
  '''
  get_number_of_ratings extracts the number of ratings the book has from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :number_of_ratings: {string} The number of ratings
  '''
  try:
    find_number_of_ratings = soup.find('meta', {'itemprop': 'ratingCount'}) # Finds the <meta> tag containg the number of ratings
    number_of_ratings = find_number_of_ratings['content'] # Extracts just the text from the tag
  except:
    number_of_ratings = '' # If the number of ratings is not found
  return number_of_ratings

# %%
def get_rating_distribution(soup):
  '''
  get_rating_distribution extracts the number of ratings for each value (1-5) from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :rating_distribution: {dictionary} The number of reviews as a string for each rating value
  '''
  try:
    rating_distribution_table = re.findall(r'\[(\d+)\, (\d+)\, (\d+)\, (\d+)\, (\d+)\]', str(soup))[0] # Finds the rating distribution
    rating_distribution = {'5': rating_distribution_table[0], # Extracts the rating distrubtion text and saves it in a dictionary
                           '4': rating_distribution_table[1],
                           '3': rating_distribution_table[2],
                           '2': rating_distribution_table[3],
                           '1': rating_distribution_table[4]}
  except:
    rating_distribution = {'5': '', 
                           '4': '',
                           '3': '',
                           '2': '',
                           '1': ''}
  return rating_distribution

# %%
def get_number_of_reviews(soup):
  '''
  get_number_of_reviews extracts the number of reviews the book has from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :number_of_reviews: {string} The number of reviews
  '''
  try:
    find_number_of_reviews = soup.find('meta', {'itemprop': 'reviewCount'}) # Finds the <mate> tag containing the number of reviews
    number_of_reviews = find_number_of_reviews['content'] # The text of the number of reviews
  except:
    number_of_reviews = '' # If the number of reviews is not found
  return number_of_reviews

# %%
def get_cover_img(soup):
  '''
  get_cover_img extracts the cover image from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :cover_img: {string} The tag for the cover image
  '''
  try:
    find_book_cover = soup.find('div', {'class': 'bookCoverPrimary'}) # Finds the <div> tag containing the cover img
    cover_img = find_book_cover.find('img')['src'] # Find the cover img
  except:
    cover_img = '' # If the cover image is not found
  return cover_img

# %%
def get_synopsis(soup):
  '''
  get_synopsis extracts the book synopsis from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :synopsis: {string} The book's synopsis
  '''
  try:
    find_synopsis = soup.find('div', {'id': 'description'}) # Finds the <div> tag containg the <span> tag
    find_synopsis_span = find_synopsis.find('span') # Finds the <span> tag containg the synopsis
    synopsis = find_synopsis_span.get_text(strip=True) # Extracts just the text from the tag
    synopsis = synopsis.replace("&apos", "'") # Fixes the apostrophes
  except:
    synopsis = '' # If the synopsis is not found
  return synopsis

# %%
def get_book_reviews(soup):
  '''
  get_book_reviews extracts the book reviews from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :book_reviews: {string} List of all of the book reviews, comma seperated
  '''
  try:
    all_reviews = [] # Initialize list
    find_book_reviews = soup.find_all('div', {'class': 'friendReviews elementListBrown'}) # Finds all the <div> tags containing reviews in <span> tags
    for book_review in find_book_reviews: # Loops through all the reviews
      find_star_rating = book_review.find_all('span', {'class', 'staticStar p10'}) # Finds all the <span> tags containing star ratings
      star_rating = str(len(find_star_rating)) # Finds the star rating
      find_review = book_review.find('span', {'class': 'readable'}) # Finds the <span> tag containg the review
      find_review_display = find_review.find_all('span') # Finds all the <span> tags containg display and not displayed reviews
      if len(find_review_display) == 1: # If only one displayed review
        full_review = find_review_display[0].get_text(strip=True) # Extracts just the text from the <span> tag with the review
      else:
        find_a = find_review.find('a', {'href': '#'}) # Finds the <a> tag containg the review id
        review_id = find_a['data-text-id'] # Extracts the user id
        id = 'freeText' + review_id # Creates the full id for the review
        find_full_review = find_review.find('span', {'id': id}) # Finds the <span> tag containing the full review using the full id
        full_review = find_full_review.get_text(strip=True) # Extracts just the text from the tag
      review = star_rating + '_' + full_review # Combines the star rating and the review
      all_reviews.append(review) # Adds the review to the list
    book_reviews = ',, '.join(all_reviews) # Joins all the reviews comma seperated
  except:
    book_reviews = '' # If the book reviews are not found
  return book_reviews

# %%
def get_goodreads_data(soup):
  '''
  get_goodreads_data extracts all of the wanted data from the BeautifulSoup object

  [Args]
  :soup: {BeautifulSoup object} Created from the book's goodreads webpage source code

  [Returns]
  :goodreads_data: {dictionary} The book's data from goodreads
  '''
  goodreads_data = {'Title': get_title(soup), 
                    'Author(s)': get_author(soup),
                    'Number in Series': get_book_number(soup),
                    'Series Title': get_series_title(soup),
                    'Length of Series': get_series_length(soup),
                    'Publication Month': get_publication_date(soup)[0],
                    'Publication Day': get_publication_date(soup)[1],
                    'Publication Year': get_publication_date(soup)[2],
                    'Number of Pages': get_number_of_pages(soup),
                    'Genres': get_genres(soup),
                    'Similar Books': get_similar_books(soup),
                    'Rating': get_rating_value(soup),
                    'Number of Ratings': get_number_of_ratings(soup),
                    'Number of 5-Star Ratings': get_rating_distribution(soup)['5'],
                    'Number of 4-Star Ratings': get_rating_distribution(soup)['4'],
                    'Number of 3-Star Ratings': get_rating_distribution(soup)['3'],
                    'Number of 2-Star Ratings': get_rating_distribution(soup)['2'],
                    'Number of 1-Star Ratings': get_rating_distribution(soup)['1'],
                    'Number of Reviews': get_number_of_reviews(soup),
                    'Cover Image Tag': get_cover_img(soup),
                    'Synopsis': get_synopsis(soup)}
  return goodreads_data

# %%
def main():
  goodreads_ids = [] # Initializes the list for the goodreads ids of each book
  with open('/content/drive/MyDrive/Colab Notebooks/Rory Gilmore Book List/goodreads_ids.txt', 'r') as f: # Opens a txt file with the goodreads ids
    for line in f: # Loop through each goodreads id
      goodreads_ids.append(line.strip()) # Clean the goodreads id and add it to the initialized list
  rg_challenge_dict = collections.defaultdict(list) # Initialize a dictionary that the goddreads data will be added to
  review_txt = '' # Initialize the string for reviews
  for goodreads_id in goodreads_ids: # Loop through each book
    url = 'https://www.goodreads.com/book/show/' + goodreads_id # The goodreads url for the book
    print(url) 
    title = '' # Initializes the value of the title
    while_count = 10 # Sets an initial value for the counter
    while not title: # Runs until the page is correctly requested, and a title can be found
      page = requests.get(url) # Gets the html webpage
      soup = BeautifulSoup(page.content, "html.parser") # Creates a parse tree
      title = get_title(soup) # Extracts the title from the parse tree
      while_count = while_count - 1 # Decrease the count
      if while_count < 0: # The loop breaks when the title is found or after it runs 10 times
        break
    goodreads_data = get_goodreads_data(soup) # Extracts all of the data from goodreads
    key_list = list(goodreads_data.keys()) # Lists the keys from the dictionary
    for key in key_list: # Loops through each key
      rg_challenge_dict[key].append(goodreads_data[key]) # Appends the books data to the dictionary
    review_txt = review_txt + 'Title: ' + title + '|| ' + get_book_reviews(soup) + ' ||| ' # Combines all of the book reviews into a string
    time.sleep(2) # Takes a break for the goodreads server
  rg_df = pd.DataFrame(rg_challenge_dict) # Converts the dictionary with data from all of the books into a datafram
  rg_df.to_csv('/content/drive/MyDrive/Colab Notebooks/Rory Gilmore Book List/goodreads_data.csv')  # Saves the dataframe as a csv file
  text_file = open("/content/drive/MyDrive/Colab Notebooks/Rory Gilmore Book List/book_reviews.txt", "w") # Creates a new txt file
  text_file.write(review_txt) # Saves the string with the reviews to the txt file
  text_file.close() # clost the txt file

# %%
if __name__ == '__main__':
    main()
# Out:
# https://www.goodreads.com/book/show/40961427-1984
# https://www.goodreads.com/book/show/1487493.Absolute_Rage
# https://www.goodreads.com/book/show/53835.The_Age_of_Innocence
# https://www.goodreads.com/book/show/2956.The_Adventures_of_Huckleberry_Finn
# https://www.goodreads.com/book/show/24583.The_Adventures_of_Tom_Sawyer
# https://www.goodreads.com/book/show/60671823-alice-s-adventures-in-wonderland
# https://www.goodreads.com/book/show/96123.All_the_President_s_Men
# https://www.goodreads.com/book/show/469571.All_the_Pretty_Horses
# https://www.goodreads.com/book/show/3985.The_Amazing_Adventures_of_Kavalier_Clay
# https://www.goodreads.com/book/show/22165.American_Steel
# https://www.goodreads.com/book/show/331319.An_American_Tragedy
# https://www.goodreads.com/book/show/16299.And_Then_There_Were_None
# https://www.goodreads.com/book/show/9800581-the-andy-warhol-diaries
# https://www.goodreads.com/book/show/252577.Angela_s_Ashes
# https://www.goodreads.com/book/show/92250.Millennium_Approaches
# https://www.goodreads.com/book/show/92254.Perestroika
# https://www.goodreads.com/book/show/15823480-anna-karenina
# https://www.goodreads.com/book/show/1714258.The_Apocalyptics
# https://www.goodreads.com/book/show/479740.The_Archidamian_War
# https://www.goodreads.com/book/show/12474.The_Armies_of_the_Night
# https://www.goodreads.com/book/show/94079.The_Art_of_Eating
# https://www.goodreads.com/book/show/10387214-the-art-of-fiction
# https://www.goodreads.com/book/show/24618.The_Art_of_Living
# https://www.goodreads.com/book/show/10534.The_Art_of_War
# https://www.goodreads.com/book/show/77013.As_I_Lay_Dying
# https://www.goodreads.com/book/show/6867.Atonement
# https://www.goodreads.com/book/show/534255.Autobiography_of_a_Face
# https://www.goodreads.com/book/show/58345.The_Awakening
# https://www.goodreads.com/book/show/646195.Babe
# https://www.goodreads.com/book/show/200883.Backlash
# https://www.goodreads.com/book/show/89623.Bad_Dirt
# https://www.goodreads.com/book/show/533465.Balzac_and_the_Little_Chinese_Seamstress
# https://www.goodreads.com/book/show/15801402-bambi
# https://www.goodreads.com/book/show/12319.Basic_Writings_of_Nietzsche
# https://www.goodreads.com/book/show/5826.Bel_Canto
# https://www.goodreads.com/book/show/6514.The_Bell_Jar
# https://www.goodreads.com/book/show/6149.Beloved
# https://www.goodreads.com/book/show/52357.Beowulf
# https://www.goodreads.com/book/show/486571.Holidays
# https://www.goodreads.com/book/show/99944.The_Bhagavad_Gita
# https://www.goodreads.com/book/show/106888.The_Big_Love
# https://www.goodreads.com/book/show/209016.The_Bielski_Brothers
# https://www.goodreads.com/book/show/392478.Billy_Budd_and_Other_Tales
# https://www.goodreads.com/book/show/179512.Bitch
# https://www.goodreads.com/book/show/125842.A_Bolt_from_the_Blue_and_Other_Essays
# https://www.goodreads.com/book/show/5129.Brave_New_World
# https://www.goodreads.com/book/show/55847195-breakfast-at-tiffany-s
# https://www.goodreads.com/book/show/18723.Brick_Lane
# https://www.goodreads.com/book/show/83674.The_Bridges_of_Madison_County
# https://www.goodreads.com/book/show/227443.Bridget_Jones_s_Diary
# https://www.goodreads.com/book/show/3869.A_Brief_History_of_Time
# https://www.goodreads.com/book/show/1038223.Brigadoon
# https://www.goodreads.com/book/show/1627.Brokeback_Mountain
# https://www.goodreads.com/book/show/763144.The_Bront_s
# https://www.goodreads.com/book/show/1852.The_Call_of_the_Wild
# https://www.goodreads.com/book/show/19380.Candide
# https://www.goodreads.com/book/show/2696.The_Canterbury_Tales
# https://www.goodreads.com/book/show/3677019-captain-corelli-s-mandolin
# https://www.goodreads.com/book/show/10592.Carrie
# https://www.goodreads.com/book/show/168668.Catch_22
# https://www.goodreads.com/book/show/5107.The_Catcher_in_the_Rye
# https://www.goodreads.com/book/show/3284885-the-celebrated-jumping-frog-of-calaveras-county
# https://www.goodreads.com/book/show/6310.Charlie_and_the_Chocolate_Factory
# https://www.goodreads.com/book/show/24178.Charlotte_s_Web
# https://www.goodreads.com/book/show/858313.The_Children_s_Hour
# https://www.goodreads.com/book/show/10629.Christine
# https://www.goodreads.com/book/show/5326.A_Christmas_Carol
# https://www.goodreads.com/book/show/858513.Chrysanthemum
# https://www.goodreads.com/book/show/17169149-cinderella
# https://www.goodreads.com/book/show/858719.Clifford_the_Big_Red_Dog
# https://www.goodreads.com/book/show/41817486-a-clockwork-orange
# https://www.goodreads.com/book/show/49628.Cloud_Atlas
# https://www.goodreads.com/book/show/9858081-the-code-of-the-woosters
# https://www.goodreads.com/book/show/12577.The_Collected_Stories
# https://www.goodreads.com/book/show/82357.The_Comedy_of_Errors
# https://www.goodreads.com/book/show/217073.Novels_1944_1962
# https://www.goodreads.com/book/show/47730.The_Complete_Poems
# https://www.goodreads.com/book/show/44453.Complete_Stories
# https://www.goodreads.com/book/show/310612.A_Confederacy_of_Dunces
# https://www.goodreads.com/book/show/162898.A_Connecticut_Yankee_in_King_Arthur_s_Court
# https://www.goodreads.com/book/show/6751.Consider_the_Lobster_and_Other_Essays
# https://www.goodreads.com/book/show/61666.Contact
# https://www.goodreads.com/book/show/7126.The_Count_of_Monte_Cristo
# https://www.goodreads.com/book/show/59144.Cousin_Bette
# https://www.goodreads.com/book/show/7144.Crime_and_Punishment
# https://www.goodreads.com/book/show/40200.The_Crimson_Petal_and_the_White
# https://www.goodreads.com/book/show/723395.The_Crisis
# https://www.goodreads.com/book/show/17250.The_Crucible
# https://www.goodreads.com/book/show/11740848-cujo
# https://www.goodreads.com/book/show/618259.The_Curious_Incident_of_the_Dog_in_the_Night_Time
# https://www.goodreads.com/book/show/15638.Cyrano_de_Bergerac
# https://www.goodreads.com/book/show/16527.Daughter_of_Fortune
# https://www.goodreads.com/book/show/1153738.Lisa_and_David
# https://www.goodreads.com/book/show/58696.David_Copperfield
# https://www.goodreads.com/book/show/968.The_Da_Vinci_Code
# https://www.goodreads.com/book/show/960.Angels_Demons
# https://www.goodreads.com/book/show/6411961-the-lost-symbol
# https://www.goodreads.com/book/show/17212231-inferno
# https://www.goodreads.com/book/show/32283133-origin
# https://www.goodreads.com/book/show/28381.Dead_Souls
# https://www.goodreads.com/book/show/12898.Death_of_a_Salesman
# https://www.goodreads.com/book/show/37735.Deenie
# https://www.goodreads.com/book/show/11041.Delta_of_Venus
# https://www.goodreads.com/book/show/5695.Demons
# https://www.goodreads.com/book/show/397483.The_Devil_in_the_White_City
# https://www.goodreads.com/book/show/18518.The_Diary_of_Virginia_Woolf_Volume_One
# https://www.goodreads.com/book/show/48855.The_Diary_of_a_Young_Girl
# https://www.goodreads.com/book/show/25378.The_Dirt
# https://www.goodreads.com/book/show/15645.Inferno
# https://www.goodreads.com/book/show/60634966-purgatorio
# https://www.goodreads.com/book/show/32812.Paradiso
# https://www.goodreads.com/book/show/137791.Divine_Secrets_of_the_Ya_Ya_Sisterhood
# https://www.goodreads.com/book/show/3836.Don_Quixote
# https://www.goodreads.com/book/show/53001341-downpour
# https://www.goodreads.com/book/show/17245.Dracula
# https://www.goodreads.com/book/show/1409344.Driving_Miss_Daisy
# https://www.goodreads.com/book/show/19501.Eat_Pray_Love
# https://www.goodreads.com/book/show/16126730-edgar-allan-poe
# https://www.goodreads.com/book/show/884536.Eleanor_Roosevelt_Volume_1
# https://www.goodreads.com/book/show/7442.The_Electric_Kool_Aid_Acid_Test
# https://www.goodreads.com/book/show/214441.Euclid_s_Elements
# https://www.goodreads.com/book/show/16200.Ella_Minnow_Pea
# https://www.goodreads.com/book/show/11378.Elmer_Gantry
# https://www.goodreads.com/book/show/24885547-eloise-at-the-plaza
# https://www.goodreads.com/book/show/5355769-the-lost-days
# https://www.goodreads.com/book/show/6969.Emma
# https://www.goodreads.com/book/show/187020.Empire_Falls
# https://www.goodreads.com/book/show/789344.Encyclopedia_Brown_Boy_Detective
# https://www.goodreads.com/book/show/7647987-essentials-of-economics
# https://www.goodreads.com/book/show/5246.Ethan_Frome
# https://www.goodreads.com/book/show/205218.Ethics
# https://www.goodreads.com/book/show/23280114-rick-steves-europe-through-the-back-door-2015
# https://www.goodreads.com/book/show/149196.Eva_Luna
# https://www.goodreads.com/book/show/256566.Everything_Is_Illuminated
# https://www.goodreads.com/book/show/12468.The_Executioner_s_Song
# https://www.goodreads.com/book/show/72716.Extravagance
# https://www.goodreads.com/book/show/13079982-fahrenheit-451
# https://www.goodreads.com/book/show/91544.The_Official_Fahrenheit_9_11_Reader
# https://www.goodreads.com/book/show/724925.The_Fall_of_the_Athenian_Empire
# https://www.goodreads.com/book/show/778558.Fat_Land
# https://www.goodreads.com/book/show/7745.Fear_and_Loathing_in_Las_Vegas
# https://www.goodreads.com/book/show/3263607-the-fellowship-of-the-ring
# https://www.goodreads.com/book/show/294951.Fiddler_on_the_Roof
# https://www.goodreads.com/book/show/11013.Finnegans_Wake
# https://www.goodreads.com/book/show/207812.Firewall
# https://www.goodreads.com/book/show/277928.The_First_Folio_of_Shakespeare
# https://www.goodreads.com/book/show/3431.The_Five_People_You_Meet_in_Heaven
# https://www.goodreads.com/book/show/202200.Flavor_of_the_Month
# https://www.goodreads.com/book/show/484531.Fletch
# https://www.goodreads.com/book/show/36576608-flowers-for-algernon
# https://www.goodreads.com/book/show/11831404-fodor-s-selected-hotels-of-europe
# https://www.goodreads.com/book/show/9799.The_Fortress_of_Solitude
# https://www.goodreads.com/book/show/2122.The_Fountainhead
# https://www.goodreads.com/book/show/35031085-frankenstein
# https://www.goodreads.com/book/show/5113.Franny_and_Zooey
# https://www.goodreads.com/book/show/104711.Freaky_Friday
# https://www.goodreads.com/book/show/91767.Frida
# https://www.goodreads.com/book/show/9593.Gal_pagos
# https://www.goodreads.com/book/show/85767.Gender_Trouble
# https://www.goodreads.com/book/show/452589.George_W_Bushisms
# https://www.goodreads.com/book/show/242514.Gidget
# https://www.goodreads.com/book/show/258945.Gigi
# https://www.goodreads.com/book/show/198691.A_Girl_from_Yamhill
# https://www.goodreads.com/book/show/68783.Girl_Interrupted
# https://www.goodreads.com/book/show/92517.The_Glass_Menagerie
# https://www.goodreads.com/book/show/251446.Glengarry_Glen_Ross
# https://www.goodreads.com/book/show/110763.The_Gnostic_Gospels
# https://www.goodreads.com/book/show/22034.The_Godfather
# https://www.goodreads.com/book/show/9777.The_God_of_Small_Things
# https://www.goodreads.com/book/show/349040.Goldilocks_Three_Bears
# https://www.goodreads.com/book/show/19288043-gone-girl
# https://www.goodreads.com/book/show/18405.Gone_with_the_Wind
# https://www.goodreads.com/book/show/59733431-goodnight-spoons
# https://www.goodreads.com/book/show/7628.The_Good_Soldier
# https://www.goodreads.com/book/show/28859.The_Gospel_According_to_Jesus_Christ
# https://www.goodreads.com/book/show/71047.The_Graduate
# https://www.goodreads.com/book/show/18114322-the-grapes-of-wrath
# https://www.goodreads.com/book/show/2623.Great_Expectations
# https://www.goodreads.com/book/show/4671.The_Great_Gatsby
# https://www.goodreads.com/book/show/387348.The_Group
# https://www.goodreads.com/book/show/7733.Gulliver_s_Travels
# https://www.goodreads.com/book/show/824871.Guys_and_Dolls
# https://www.goodreads.com/book/show/1966425.Haiku_Volume_2
# https://www.goodreads.com/book/show/1420.Hamlet
# https://www.goodreads.com/book/show/98573.Harold_and_the_Purple_Crayon
# https://www.goodreads.com/book/show/6.Harry_Potter_and_the_Goblet_of_Fire
# https://www.goodreads.com/book/show/3.Harry_Potter_and_the_Sorcerer_s_Stone
# https://www.goodreads.com/book/show/4953.A_Heartbreaking_Work_of_Staggering_Genius
# https://www.goodreads.com/book/show/4900.Heart_of_Darkness
# https://www.goodreads.com/book/show/22324287-hell-s-angels-the-strange-and-terrible-saga-of-the-outlaw-motorcycle-ga
# https://www.goodreads.com/book/show/105992.Helter_Skelter
# https://www.goodreads.com/book/show/229443.Henry_IV_Part_I
# https://www.goodreads.com/book/show/34431.Henry_IV_Part_2
# https://www.goodreads.com/book/show/37526.Henry_V
# https://www.goodreads.com/book/show/82378.Henry_VI
# https://www.goodreads.com/book/show/10412.He_s_Just_Not_That_Into_You
# https://www.goodreads.com/book/show/285092.High_Fidelity
# https://www.goodreads.com/book/show/29223655-the-history-of-the-decline-and-fall-of-the-roman-empire-all-6-volumes
# https://www.goodreads.com/book/show/261243.History_of_the_Peloponnesian_War
# https://www.goodreads.com/book/show/8188696-the-history-of-tom-thumb-and-other-stories
# https://www.goodreads.com/book/show/70292.Hockey_For_Dummies
# https://www.goodreads.com/book/show/688027.Holidays_on_Ice
# https://www.goodreads.com/book/show/2036549.The_Holy_Barbarians
# https://www.goodreads.com/book/show/7779.Horton_Hears_a_Who_
# https://www.goodreads.com/book/show/38311414-house-of-sand-and-fog
# https://www.goodreads.com/book/show/9328.The_House_of_the_Spirits
# https://www.goodreads.com/book/show/6295.Howl_and_Other_Poems
# https://www.goodreads.com/book/show/47975.How_to_Breathe_Underwater
# https://www.goodreads.com/book/show/113946.How_the_Grinch_Stole_Christmas_
# https://www.goodreads.com/book/show/251052.How_the_Light_Gets_In
# https://www.goodreads.com/book/show/4955.How_We_Are_Hungry
# https://www.goodreads.com/book/show/62851.The_Human_Factor
# https://www.goodreads.com/book/show/30597.The_Hunchback_of_Notre_Dame
# https://www.goodreads.com/book/show/8765.I_Feel_Bad_About_My_Neck
# https://www.goodreads.com/book/show/1371.The_Iliad
# https://www.goodreads.com/book/show/50039.I_m_with_the_Band
# https://www.goodreads.com/book/show/168642.In_Cold_Blood
# https://www.goodreads.com/book/show/104260.Indiana
# https://www.goodreads.com/book/show/28385.In_the_Shadow_of_Young_Girls_in_Flower
# https://www.goodreads.com/book/show/253264.Inherit_the_Wind
# https://www.goodreads.com/book/show/618944.The_Invitation
# https://www.goodreads.com/book/show/267243.Ironweed
# https://www.goodreads.com/book/show/88631.It_Takes_a_Village
# https://www.goodreads.com/book/show/10210.Jane_Eyre
# https://www.goodreads.com/book/show/7763.The_Joy_Luck_Club
# https://www.goodreads.com/book/show/13006.Julius_Caesar
# https://www.goodreads.com/book/show/41681.The_Jungle
# https://www.goodreads.com/book/show/77270.The_Jungle_Book
# https://www.goodreads.com/book/show/40604658-jurassic-park
# https://www.goodreads.com/book/show/419916.Just_a_Couple_of_Days
# https://www.goodreads.com/book/show/95141.The_Kitchen_Boy
# https://www.goodreads.com/book/show/33313.Kitchen_Confidential
# https://www.goodreads.com/book/show/77203.The_Kite_Runner
# https://www.goodreads.com/book/show/32049.Lady_Chatterley_s_Lover
# https://www.goodreads.com/book/show/41025498-larousse-wine
# https://www.goodreads.com/book/show/284429.The_Last_Empire
# https://www.goodreads.com/book/show/19809.The_Last_Lion
# https://www.goodreads.com/book/show/55751.The_Last_Lion
# https://www.goodreads.com/book/show/746673.The_Last_Lion
# https://www.goodreads.com/book/show/1368981.The_Last_Word_and_Other_Stories
# https://www.goodreads.com/book/show/27494.Leaves_of_Grass
# https://www.goodreads.com/book/show/158725.The_Legend_of_Bagger_Vance
# https://www.goodreads.com/book/show/36377471-les-miserables
# https://www.goodreads.com/book/show/9915.Less_Than_Zero
# https://www.goodreads.com/book/show/731031.Letters_of_Ayn_Rand
# https://www.goodreads.com/book/show/2967975-the-letters-of-edith-wharton
# https://www.goodreads.com/book/show/46199.Letters_to_a_Young_Poet
# https://www.goodreads.com/book/show/6251772-the-libation-bearers
# https://www.goodreads.com/book/show/1524.Agamemnon
# https://www.goodreads.com/book/show/3332967-eumenides
# https://www.goodreads.com/book/show/23577.Lies_the_Lying_Liars_Who_Tell_Them
# https://www.goodreads.com/book/show/22318578-the-life-changing-magic-of-tidying-up
# https://www.goodreads.com/book/show/4214.Life_of_Pi
# https://www.goodreads.com/book/show/688826.The_Life_of_Samuel_Johnson
# https://www.goodreads.com/book/show/6952.Like_Water_for_Chocolate
# https://www.goodreads.com/book/show/100915.The_Lion_the_Witch_and_the_Wardrobe
# https://www.goodreads.com/book/show/31250.Little_Dorrit
# https://www.goodreads.com/book/show/8337.Little_House_in_the_Big_Woods
# https://www.goodreads.com/book/show/77767.Little_House_on_the_Prairie
# https://www.goodreads.com/book/show/8252.Farmer_Boy
# https://www.goodreads.com/book/show/7882.On_the_Banks_of_Plum_Creek
# https://www.goodreads.com/book/show/8248.By_the_Shores_of_Silver_Lake
# https://www.goodreads.com/book/show/8282.The_Long_Winter
# https://www.goodreads.com/book/show/8253.Little_Town_on_the_Prairie
# https://www.goodreads.com/book/show/77770.These_Happy_Golden_Years
# https://www.goodreads.com/book/show/8296.The_First_Four_Years
# https://www.goodreads.com/book/show/733977.The_Little_Locksmith
# https://www.goodreads.com/book/show/342994.The_Little_Match_Girl
# https://www.goodreads.com/book/show/1934.Little_Women
# https://www.goodreads.com/book/show/56073.Living_History
# https://www.goodreads.com/book/show/7604.Lolita
# https://www.goodreads.com/book/show/7624.Lord_of_the_Flies
# https://www.goodreads.com/book/show/12194.Lord_Jim
# https://www.goodreads.com/book/show/89723.The_Lottery_and_Other_Stories
# https://www.goodreads.com/book/show/12232938-the-lovely-bones
# https://www.goodreads.com/book/show/73968.Love_Story
# https://www.goodreads.com/book/show/8852.Macbeth
# https://www.goodreads.com/book/show/2175.Madame_Bovary
# https://www.goodreads.com/book/show/475339.Madeline
# https://www.goodreads.com/book/show/114496.The_Manticore
# https://www.goodreads.com/book/show/74406.Fifth_Business
# https://www.goodreads.com/book/show/41098.World_of_Wonders
# https://www.goodreads.com/book/show/21796.Marathon_Man
# https://www.goodreads.com/book/show/152380.Mary_Poppins
# https://www.goodreads.com/book/show/117833.The_Master_and_Margarita
# https://www.goodreads.com/book/show/231083.The_Principia
# https://www.goodreads.com/book/show/11541819-matisse
# https://www.goodreads.com/book/show/722710.The_Meaning_of_Consuelo
# https://www.goodreads.com/book/show/28139847-the-meditations-of-marcus-aurelius
# https://www.goodreads.com/book/show/164006.Memoirs_of_a_Dutiful_Daughter
# https://www.goodreads.com/book/show/23797698-the-memoirs-of-general-william-t-sherman
# https://www.goodreads.com/book/show/1274.Men_Are_from_Mars_Women_Are_from_Venus
# https://www.goodreads.com/book/show/300841.A_Mencken_Chrestomathy
# https://www.goodreads.com/book/show/104778.The_Merry_Wives_of_Windsor
# https://www.goodreads.com/book/show/4137.Me_Talk_Pretty_One_Day
# https://www.goodreads.com/book/show/485894.The_Metamorphosis
# https://www.goodreads.com/book/show/2187.Middlesex
# https://www.goodreads.com/book/show/1622.A_Midsummer_Night_s_Dream
# https://www.goodreads.com/book/show/22327.The_Miracle_Worker
# https://www.goodreads.com/book/show/10614.Misery
# https://www.goodreads.com/book/show/211953.Mistress_of_Mellyn
# https://www.goodreads.com/book/show/153747.Moby_Dick_or_the_Whale
# https://www.goodreads.com/book/show/893037.The_Mojo_Collection
# https://www.goodreads.com/book/show/8090909-moli-re
# https://www.goodreads.com/book/show/446542.Molloy
# https://www.goodreads.com/book/show/374671.Mommie_Dearest
# https://www.goodreads.com/book/show/7410.A_Monetary_History_of_the_United_States_1867_1960
# https://www.goodreads.com/book/show/379255.Monsieur_Proust
# https://www.goodreads.com/book/show/722041.A_Month_of_Sundays
# https://www.goodreads.com/book/show/911140.Motley_Crue
# https://www.goodreads.com/book/show/7008439-the-mourning-bride
# https://www.goodreads.com/book/show/55985836-a-movable-feast
# https://www.goodreads.com/book/show/14942.Mrs_Dalloway
# https://www.goodreads.com/book/show/844051.Mutiny_on_the_Bounty
# https://www.goodreads.com/book/show/238727.My_First_Summer_in_the_Sierra
# https://www.goodreads.com/book/show/309942.My_Lai_4
# https://www.goodreads.com/book/show/1109271.My_Life_As_Author_And_Editor
# https://www.goodreads.com/book/show/180435.My_Life_in_Orange
# https://www.goodreads.com/book/show/2764420-myra-waldo-s-travel-and-motoring-guide-to-europe
# https://www.goodreads.com/book/show/10917.My_Sister_s_Keeper
# https://www.goodreads.com/book/show/39323821-my-struggle
# https://www.goodreads.com/book/show/12467.The_Naked_and_the_Dead
# https://www.goodreads.com/book/show/7437.Naked_Lunch
# https://www.goodreads.com/book/show/119073.The_Name_of_the_Rose
# https://www.goodreads.com/book/show/33917.The_Namesake
# https://www.goodreads.com/book/show/302874.The_Witch_Tree_Symbol
# https://www.goodreads.com/book/show/228333.The_Nanny_Diaries
# https://www.goodreads.com/book/show/15622.Native_Son
# https://www.goodreads.com/book/show/75243.Nature_s_Metropolis
# https://www.goodreads.com/book/show/697542.Nervous_System
# https://www.goodreads.com/book/show/108128.New_Poems_of_Emily_Dickinson
# https://www.goodreads.com/book/show/109533.The_New_Way_Things_Work
# https://www.goodreads.com/book/show/325085.Nicholas_Nickleby
# https://www.goodreads.com/book/show/1869.Nickel_and_Dimed
# https://www.goodreads.com/book/show/1617.Night
# https://www.goodreads.com/book/show/6597341-no-man-is-an-island-a-selection-from-the-prose
# https://www.goodreads.com/book/show/50398.Northanger_Abbey
# https://www.goodreads.com/book/show/47173.The_Norton_Anthology_of_Theory_and_Criticism
# https://www.goodreads.com/book/show/38502.Notes_of_a_Dirty_Old_Man
# https://www.goodreads.com/book/show/92286.Novels_1930_1942
# https://www.goodreads.com/book/show/685606.November_of_the_Heart
# https://www.goodreads.com/book/show/1381.The_Odyssey
# https://www.goodreads.com/book/show/1554.Oedipus_Rex
# https://www.goodreads.com/book/show/31548.Of_Human_Bondage
# https://www.goodreads.com/book/show/890.Of_Mice_and_Men
# https://www.goodreads.com/book/show/2165.The_Old_Man_and_the_Sea
# https://www.goodreads.com/book/show/40940082-old-school
# https://www.goodreads.com/book/show/18254.Oliver_Twist
# https://www.goodreads.com/book/show/1896842.On_the_Contrary
# https://www.goodreads.com/book/show/17125.One_Day_in_the_Life_of_Ivan_Denisovich
# https://www.goodreads.com/book/show/332613.One_Flew_Over_the_Cuckoo_s_Nest
# https://www.goodreads.com/book/show/320.One_Hundred_Years_of_Solitude
# https://www.goodreads.com/book/show/6329013-on-the-origin-of-species
# https://www.goodreads.com/book/show/70401.On_the_Road
# https://www.goodreads.com/book/show/97331.The_Opposite_of_Fate
# https://www.goodreads.com/book/show/10006.Oracle_Night
# https://www.goodreads.com/book/show/30486192-orations-of-american-orators
# https://www.goodreads.com/book/show/46756.Oryx_and_Crake
# https://www.goodreads.com/book/show/12996.Othello
# https://www.goodreads.com/book/show/31244.Our_Mutual_Friend
# https://www.goodreads.com/book/show/272545.The_Outbreak_of_the_Peloponnesian_War
# https://www.goodreads.com/book/show/10964.Outlander
# https://www.goodreads.com/book/show/781787.Out_of_Africa
# https://www.goodreads.com/book/show/231804.The_Outsiders
# https://www.goodreads.com/book/show/26849404-the-oxford-complete-works-of-shakespeare
# https://www.goodreads.com/book/show/45195.A_Passage_to_India
# https://www.goodreads.com/book/show/272546.The_Peace_of_Nicias_and_the_Sicilian_Expedition
# https://www.goodreads.com/book/show/22628.The_Perks_of_Being_a_Wallflower
# https://www.goodreads.com/book/show/128939.The_Persian_Puzzle
# https://www.goodreads.com/book/show/95420.Personal_History
# https://www.goodreads.com/book/show/526869.Peyton_Place
# https://www.goodreads.com/book/show/5297.The_Picture_of_Dorian_Gray
# https://www.goodreads.com/book/show/638430.Pigs_at_the_Trough
# https://www.goodreads.com/book/show/180617.Pinocchio
# https://www.goodreads.com/book/show/14595.Please_Kill_Me
# https://www.goodreads.com/book/show/39889155-plutarch-s-lives
# https://www.goodreads.com/book/show/294394.Tennyson
# https://www.goodreads.com/book/show/1771494.Points_of_View
# https://www.goodreads.com/book/show/4260.The_Polysyllabic_Spree
# https://www.goodreads.com/book/show/2143896.Pomeranian
# https://www.goodreads.com/book/show/44450.The_Portable_Dorothy_Parker
# https://www.goodreads.com/book/show/80447.The_Portable_Nietzsche
# https://www.goodreads.com/book/show/113720.The_Price_of_Loyalty
# https://www.goodreads.com/book/show/1885.Pride_and_Prejudice
# https://www.goodreads.com/book/show/261444.Primary_Colors
# https://www.goodreads.com/book/show/21787.The_Princess_Bride
# https://www.goodreads.com/book/show/40605609-property
# https://www.goodreads.com/book/show/361773.The_Pump_House_Gang
# https://www.goodreads.com/book/show/235095.Punk
# https://www.goodreads.com/book/show/50725.The_Pursuit_of_Love_Love_in_a_Cold_Climate
# https://www.goodreads.com/book/show/111723.Pushkin
# https://www.goodreads.com/book/show/7714.Pygmalion
# https://www.goodreads.com/book/show/733957.Quattrocento
# https://www.goodreads.com/book/show/199157.A_Quiet_Storm
# https://www.goodreads.com/book/show/947334.Quiller_Bamboo
# https://www.goodreads.com/book/show/17160901-rapunzel
# https://www.goodreads.com/book/show/31196.The_Razor_s_Edge
# https://www.goodreads.com/book/show/7603.Reading_Lolita_in_Tehran
# https://www.goodreads.com/book/show/17899948-rebecca
# https://www.goodreads.com/book/show/17529.Rebecca_of_Sunnybrook_Farm
# https://www.goodreads.com/book/show/35220.The_Red_Badge_of_Courage
# https://www.goodreads.com/book/show/4989.The_Red_Tent
# https://www.goodreads.com/book/show/6984597-rescuing-patty-hearst
# https://www.goodreads.com/book/show/838729.The_Return_of_the_King
# https://www.goodreads.com/book/show/335090.Revolution_from_Within
# https://www.goodreads.com/book/show/42058.Richard_III
# https://www.goodreads.com/book/show/64862.R_is_for_Ricochet
# https://www.goodreads.com/book/show/39664.Rita_Hayworth_and_Shawshank_Redemption
# https://www.goodreads.com/book/show/778639.Robert_s_Rules_of_Order
# https://www.goodreads.com/book/show/8576497-roman-fever
# https://www.goodreads.com/book/show/18135.Romeo_and_Juliet
# https://www.goodreads.com/book/show/18521.A_Room_of_One_s_Own
# https://www.goodreads.com/book/show/3087.A_Room_with_a_View
# https://www.goodreads.com/book/show/228296.Rosemary_s_Baby
# https://www.goodreads.com/book/show/2156320.The_Rough_Guide_to_Europe_2005
# https://www.goodreads.com/book/show/103236.Sacred_Time
# https://www.goodreads.com/book/show/676.Sailing_Alone_Around_the_Room
# https://www.goodreads.com/book/show/18789.Sanctuary
# https://www.goodreads.com/book/show/12781.The_Satanic_Verses
# https://www.goodreads.com/book/show/12335.Savage_Beauty
# https://www.goodreads.com/book/show/59580322-say-goodbye-to-daisy-miller
# https://www.goodreads.com/book/show/135288.The_Scarecrow_of_Oz
# https://www.goodreads.com/book/show/12296.The_Scarlet_Letter
# https://www.goodreads.com/book/show/375013.Schindler_s_List
# https://www.goodreads.com/book/show/110737.Seabiscuit
# https://www.goodreads.com/book/show/457264.The_Second_Sex
# https://www.goodreads.com/book/show/37435.The_Secret_Life_of_Bees
# https://www.goodreads.com/book/show/89840.Secrets_of_the_Flesh
# https://www.goodreads.com/book/show/1372222.The_Selected_Letters_of_Dawn_Powell
# https://www.goodreads.com/book/show/14935.Sense_and_Sensibility
# https://www.goodreads.com/book/show/5148.A_Separate_Peace
# https://www.goodreads.com/book/show/7455.Sex_and_the_City
# https://www.goodreads.com/book/show/252.Sexus
# https://www.goodreads.com/book/show/1232.The_Shadow_of_the_Wind
# https://www.goodreads.com/book/show/25740581-shane
# https://www.goodreads.com/book/show/11588.The_Shining
# https://www.goodreads.com/book/show/52036.Siddhartha
# https://www.goodreads.com/book/show/142079.S_is_for_Silence
# https://www.goodreads.com/book/show/23856.The_Sisters
# https://www.goodreads.com/book/show/196301.The_Skin_of_Our_Teeth
# https://www.goodreads.com/book/show/4981.Slaughterhouse_Five
# https://www.goodreads.com/book/show/13543257-sleeping-beauty
# https://www.goodreads.com/book/show/44001.Small_Island
# https://www.goodreads.com/book/show/30317485-the-snows-of-kilimanjaro
# https://www.goodreads.com/book/show/20746724-snow-white-and-rose-red
# https://www.goodreads.com/book/show/22483.Social_Origins_of_Dictatorship_and_Democracy
# https://www.goodreads.com/book/show/248596.Something_Wicked_This_Way_Comes
# https://www.goodreads.com/book/show/4261.Songbook
# https://www.goodreads.com/book/show/733768.The_Song_of_Names
# https://www.goodreads.com/book/show/202839.The_Song_Reader
# https://www.goodreads.com/book/show/165251.Song_of_the_Simple_Truth
# https://www.goodreads.com/book/show/21282213-sonnet-43
# https://www.goodreads.com/book/show/21374347-the-sonnets---william-shakespeare
# https://www.goodreads.com/book/show/154387.Sonnets_from_the_Portuguese
# https://www.goodreads.com/book/show/228560.Sophie_s_Choice
# https://www.goodreads.com/book/show/10975.The_Sound_and_the_Fury
# https://www.goodreads.com/book/show/30594.Speak_Memory
# https://www.goodreads.com/book/show/8625663-stalin
# https://www.goodreads.com/book/show/52350.The_Stepford_Wives
# https://www.goodreads.com/book/show/32145.Stiff
# https://www.goodreads.com/book/show/325421.The_Story_of_Doctor_Dolittle
# https://www.goodreads.com/book/show/821611.The_Story_of_My_Life
# https://www.goodreads.com/book/show/40483.Story_of_O
# https://www.goodreads.com/book/show/15848107-the-strange-case-of-dr-jekyll-and-mr-hyde
# https://www.goodreads.com/book/show/12220.A_Streetcar_Named_Desire
# https://www.goodreads.com/book/show/138959.Stuart_Little
# https://www.goodreads.com/book/show/170939.Summer_of_Fear
# https://www.goodreads.com/book/show/3876.The_Sun_Also_Rises
# https://www.goodreads.com/book/show/12749.Swann_s_Way
# https://www.goodreads.com/book/show/990494.Swimming_with_Giants
# https://www.goodreads.com/book/show/67920.Sybil
# https://www.goodreads.com/book/show/1953.A_Tale_of_Two_Cities
# https://www.goodreads.com/book/show/46164.Tender_Is_the_Night
# https://www.goodreads.com/book/show/63461.Terms_of_Endearment
# https://www.goodreads.com/book/show/32736.Tevye_the_Dairyman_and_the_Railroad_Stories
# https://www.goodreads.com/book/show/31326.Theatre
# https://www.goodreads.com/book/show/152052.They_Shoot_Horses_Don_t_They_
# https://www.goodreads.com/book/show/80616.The_Thin_Man
# https://www.goodreads.com/book/show/337039.Thunder
# https://www.goodreads.com/book/show/40526.Time_and_Again
# https://www.goodreads.com/book/show/7669.Timeline
# https://www.goodreads.com/book/show/18619684-the-time-traveler-s-wife
# https://www.goodreads.com/book/show/4630.To_Have_and_Have_Not
# https://www.goodreads.com/book/show/2657.To_Kill_a_Mockingbird
# https://www.goodreads.com/book/show/154392.The_Town_and_the_City
# https://www.goodreads.com/book/show/35750773-the-tragedy-of-king-richard-iii
# https://www.goodreads.com/book/show/135836.Trainspotting
# https://www.goodreads.com/book/show/14891.A_Tree_Grows_in_Brooklyn
# https://www.goodreads.com/book/show/17690.The_Trial
# https://www.goodreads.com/book/show/9987160-trouble-in-our-backyard
# https://www.goodreads.com/book/show/394172.The_True_and_Outstanding_Adventures_of_the_Hunt_Sisters
# https://www.goodreads.com/book/show/827837.Truth_Beauty
# https://www.goodreads.com/book/show/222910.The_Two_Towers
# https://www.goodreads.com/book/show/6900.Tuesdays_with_Morrie
# https://www.goodreads.com/book/show/338798.Ulysses
# https://www.goodreads.com/book/show/11623.The_Unabridged_Journals_of_Sylvia_Plath
# https://www.goodreads.com/book/show/9717.The_Unbearable_Lightness_of_Being
# https://www.goodreads.com/book/show/46787.Uncle_Tom_s_Cabin
# https://www.goodreads.com/book/show/194805.Understanding_Power
# https://www.goodreads.com/book/show/74462.Unless
# https://www.goodreads.com/book/show/2410348.Us_Foreign_Policy_and_the_Iran_Hostage_Crisis
# https://www.goodreads.com/book/show/581811.Valley_of_the_Dolls
# https://www.goodreads.com/book/show/572268.The_Vanishing_Newspaper
# https://www.goodreads.com/book/show/5797.Vanity_Fair
# https://www.goodreads.com/book/show/25415409-the-velvet-underground-s-the-velvet-underground-and-nico
# https://www.goodreads.com/book/show/10956.The_Virgin_Suicides
# https://www.goodreads.com/book/show/123969.Visions_of_Cody
# https://www.goodreads.com/book/show/17716.Waiting_for_Godot
# https://www.goodreads.com/book/show/16902.Walden
# https://www.goodreads.com/book/show/656.War_and_Peace
# https://www.goodreads.com/book/show/160106.We_Owe_You_Nothing
# https://www.goodreads.com/book/show/6932.What_Color_Is_Your_Parachute_A_Practical_Manual_for_Job_Hunters_and_Career_Changers
# https://www.goodreads.com/book/show/374988.What_Ever_Happened_to_Baby_Jane_
# https://www.goodreads.com/book/show/764073.When_the_Emperor_Was_Divine
# https://www.goodreads.com/book/show/6192234-when-everything-changed
# https://www.goodreads.com/book/show/14940.Who_s_Afraid_of_Virginia_Woolf_
# https://www.goodreads.com/book/show/4894.Who_Moved_My_Cheese_
# https://www.goodreads.com/book/show/37442.Wicked
# https://www.goodreads.com/book/show/12262741-wild
# https://www.goodreads.com/book/show/24108.The_Wine_Bible
# https://www.goodreads.com/book/show/217518.The_Witches_of_Eastwick
# https://www.goodreads.com/book/show/236093.The_Wonderful_Wizard_of_Oz
# https://www.goodreads.com/book/show/6185.Wuthering_Heights
# https://www.goodreads.com/book/show/159582.The_Yearling
# https://www.goodreads.com/book/show/7815.The_Year_of_Magical_Thinking
# https://www.goodreads.com/book/show/880633.Yoga_for_dummies
# https://www.goodreads.com/book/show/53639.Zorba_the_Greek
# https://www.goodreads.com/book/show/15881.Harry_Potter_and_the_Chamber_of_Secrets
# https://www.goodreads.com/book/show/5.Harry_Potter_and_the_Prisoner_of_Azkaban
# https://www.goodreads.com/book/show/2.Harry_Potter_and_the_Order_of_the_Phoenix
# https://www.goodreads.com/book/show/1.Harry_Potter_and_the_Half_Blood_Prince
# https://www.goodreads.com/book/show/136251.Harry_Potter_and_the_Deathly_Hallows
# https://www.goodreads.com/book/show/13496.A_Game_of_Thrones
# https://www.goodreads.com/book/show/10572.A_Clash_of_Kings
# https://www.goodreads.com/book/show/62291.A_Storm_of_Swords
# https://www.goodreads.com/book/show/13497.A_Feast_for_Crows
# https://www.goodreads.com/book/show/10664113-a-dance-with-dragons
# https://www.goodreads.com/book/show/102868.A_Study_in_Scarlet
# https://www.goodreads.com/book/show/608474.The_Sign_of_Four
# https://www.goodreads.com/book/show/3590.The_Adventures_of_Sherlock_Holmes
# https://www.goodreads.com/book/show/194373.The_Memoirs_of_Sherlock_Holmes
# https://www.goodreads.com/book/show/8921.The_Hound_of_the_Baskervilles
# https://www.goodreads.com/book/show/194366.The_Return_of_Sherlock_Holmes
# https://www.goodreads.com/book/show/736131.The_Valley_of_Fear
# https://www.goodreads.com/book/show/754713.His_Last_Bow
# https://www.goodreads.com/book/show/162823.The_Case_Book_of_Sherlock_Holmes
